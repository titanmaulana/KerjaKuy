# %% [markdown]
# # Job Recommendations
#
# This notebook creates a model, to recommend job positions given a position requirements description . This is done only for IT jobs.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
from sklearn.preprocessing import LabelEncoder
from sklearn.mixture import GaussianMixture
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score, auc, roc_curve, roc_auc_score
import re

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\INES\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\INES\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data = pd.read_excel(r"C:\ikhsan\UNAIR\MBKM\Bangkit\1. Capstone\data website indeed Jakarta (data 30 May 2023).xlsx", "clean data")
print(data.columns)
# selecting only IT Jobs
df = data
# selecting 
cols = ['Kualifikasi', 'Posisi', 'Deskripsi Pekerjaan ', 'Tipe Pekerjaan']
df = df[cols]
df.head(5)
# Out:
# Index(['Posisi', 'Perusahaan ', 'Lokasi', 'Salary (minimum per bulan)',
#        'Tipe Pekerjaan', 'Kualifikasi', 'Deskripsi Pekerjaan ', 'Link'],
#       dtype='object')
#                                          Kualifikasi
# 0  Wanita\nUsia maksimal 30 tahun\nMemiliki penga...  \
# 1  Technical requirements to perform the work\nAc...
# 2  Pria & Wanita \n18 - 25 tahun \nMin. pengalama...
# 3  Pria atau Wanita\nUsia maksimal 26 tahun\nTing...
# 4  Usia Maksimal 30 tahun\nPendidikan Minimal Lul...
#
#                                     Posisi
# 0      Talent Host Streaming ( Freelance )  \
# 1                             Data Analyst
# 2                        Staff Operational
# 3  Server Tasty Kitchen (Area Jabodetabek)
# 4                Admin Online (Cengkareng)
#
#                                 Deskripsi Pekerjaan  Tipe Pekerjaan
# 0  Melakukan penjualan produk secara live di Tik ...      Part-time
# 1  Work up to 20 hours per week.\nEarn a competit...      Part-time
# 2                                                NaN      Full-time
# 3                                                NaN      Part-time
# 4                                                NaN      Full-time

# %% [markdown]
# # Modifying Job Titles
# Selecting only top 21 job titles, to manage class imbalance

# %%
classes = df['Posisi'].value_counts()
keys = classes.keys().to_list()

df = df[df['Posisi'].isin(keys)]
df['Posisi'].value_counts()
# Out:
# Posisi
# Telemarketing                  5
# Staff Gudang                   5
# Cook Helper                    4
# Kasir                          3
# Beautician                     2
#                               ..
# KYC Agent                      1
# Talent / Model [Min LD 100]    1
# Guru Geografi                  1
# SPG / SPB Elektronik           1
# Staff Logistik (SLO-03)        1
# Name: count, Length: 287, dtype: int64

# %% [markdown]
# Change job titles to base title. For exmaple, chaning Senior Java Developer to Java Developer.

# %%
posisiFix = []
for i in df['Posisi']:
    i = re.sub("\(.*?\)|\[.*?\]|-.*", "", i)
    # print(i)
    posisiFix.append(i)

# print(posisiFix)
posisiFix = pd.DataFrame(posisiFix)
# posisiFix.head(5)
df['Posisi'] = posisiFix[0].values
df['Posisi'].value_counts()
# Out:
# Posisi
# Telemarketing                          5
# Staff Gudang                           5
# Cook Helper                            4
# Kasir                                  3
# Sales Advisor                          2
#                                       ..
# Housekeeping                           1
# Customer Service Specialist            1
# FREELANCE Live Streamer Marketplace    1
# KYC Agent                              1
# Staff Logistik                         1
# Name: count, Length: 282, dtype: int64

# %% [markdown]
# # Building custom tokenizer to process text

# %%
from nltk import word_tokenize          
from nltk.stem import WordNetLemmatizer 
class LemmaTokenizer(object):
    def __init__(self):
        # lemmatize text - convert to base form 
        self.wnl = WordNetLemmatizer()
        # creating stopwords list, to ignore lemmatizing stopwords 
        self.stopwords = stopwords.words('indonesian')
    def __call__(self, doc):
        return [self.wnl.lemmatize(t) for t in word_tokenize(doc) if t not in self.stopwords]

# removing new line characters, and certain hypen patterns                  
df['Kualifikasi'] = df['Kualifikasi'].apply(lambda x: x.replace('\n', ' ').replace('\r', '').replace('- ', ''). replace(' - ', ' to '))

# %% [markdown]
# # Featurizing Text

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# train features and labels 
y = df['Posisi']
X = df['Kualifikasi']

# allPreferensi = []
# for i in range(0, 3):
#     preferensi = input("Masukkan preferensi: ")
#     allPreferensi.append(preferensi)
#     if i < 2:
#         answer = input("Mau tambah preferensi?")
#     if answer != ("Y" or "Yes" or "y" or "ya"):
#         break
# strPreferensi = ', '.join(allPreferensi)
# preferensi = [strPreferensi]
# X = pd.DataFrame(preferensi, columns = ["Preferensi"])

# tdif feature rep 
vectorizer = TfidfVectorizer(tokenizer=LemmaTokenizer(), stop_words=stopwords.words('indonesian'))
vectorizer.fit(X)

# transoforming text to tdif features
tfidf_matrix = vectorizer.transform(X)

# sparse matrix to dense matrix for training
X_tdif = tfidf_matrix.toarray()

# encoding text labels in categories 
enc = LabelEncoder() 
enc.fit(y.values)
y_enc=enc.transform(y.values)

X_train_words, X_test_words, y_train, y_test = train_test_split(X, y_enc, test_size=0.15, random_state=10)

X_train = vectorizer.transform(X_train_words)
X_train = X_train.toarray()

X_test = vectorizer.transform(X_test_words)
X_test = X_test.toarray()
# Out:
# c:\Users\INES\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\feature_extraction\text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %% [markdown]
# # Training Naive Bayes
# Looks pretty overfit

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
gnb = GaussianNB()
train_preds = gnb.fit(X_train, y_train).predict(X_train)
test_preds = gnb.predict(X_test)

print('Train acc: {0}'.format(accuracy_score(y_train, train_preds)))
print('Test acc: {0}'.format(accuracy_score(y_test, test_preds)))
# Out:
# Train acc: 0.9433962264150944
# Test acc: 0.02127659574468085

# %% [markdown]
# # Training Logistic Regression
# By modifiying the maximum number of iterations, and regularization, C, the above experienced overfitting was reduced significantly

# %%
from sklearn.linear_model import LogisticRegression

logistic = LogisticRegression(max_iter=100,verbose=1, C=60)

train_preds = logistic.fit(X_train, y_train).predict(X_train)
test_preds = logistic.predict(X_test)

print('Train acc: {0}'.format(accuracy_score(y_train, train_preds)))
print('Test acc: {0}'.format(accuracy_score(y_test, test_preds)))
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Train acc: 0.9433962264150944
# Test acc: 0.0425531914893617
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    5.0s finished

# %% [markdown]
# # Creating Job Recommendations
# Recommends 2 job position alternatives given a job requirement. By obtaining probability of class predictions, and picking the top N predictions, other than true label, N closest recommendations can be got

# %%
preds_data = {'Current Position Requirments': [], 'Current Position': [], 'Alternative 1': [], 'Alternative 2': []}
y_preds_proba = logistic.predict_proba(X_test)

counter = 0 
for idx, (pred_row, true_job_position) in enumerate(zip(y_preds_proba, y_test)):
    class_preds = np.argsort(pred_row)
    # delete true class
    for i in [-1, -2]:
        if class_preds[i] == true_job_position:
            class_preds=np.delete(class_preds,i)
    # getting other 2 highest job predictions         
    top_classes = class_preds[-2:]
    # obtaining class name string from int label 
    class_names = enc.inverse_transform(top_classes)
    true_job_position_name = enc.inverse_transform([true_job_position])
    # saving to dict
    preds_data['Current Position Requirments'].append(X_test_words.iloc[idx])
    preds_data['Current Position'].append(true_job_position_name[0])
    preds_data['Alternative 1'].append(class_names[1])
    preds_data['Alternative 2'].append(class_names[0])

    
    counter +=1

# %%
preds_df = pd.DataFrame.from_dict(preds_data)
preds_df.to_csv('Recommendations.csv', index=False)
preds_df
# Out:
#                          Current Position Requirments
# 0   Pria, usia maks. 35 tahun Pendidikan Min. SMA/...  \
# 1   Pendidikan SMK/SMA, D3, S1 Penempatan Sebakis ...
# 2   Pria / Wanita Minimal Pendidikan SMA/SMK/Seder...
# 3   Pendidikan SMA/SLTA  Pengalaman minimal 1 tahu...
# 4   Wanita, minimal lulusan SMA/K Boleh Fresh Grad...
# 5   Technical requirements to perform the work Acc...
# 6   Pria & wanita maks. 40 tahun Min. pendidikan S...
# 7   Usia 18 45 tahun Pendidikan min SMA / SMK / Pa...
# 8   PRIA / WANITA MINIMAL 18 S.D 40 TAHUN MEMILIKI...
# 9   Min. SMA/SMK seluruh jurusan  Memiliki keterta...
# 10  Pendidikan Min SMA/Sederajat Usia min 19-45 Ta...
# 11  Pengalaman kerja minimal 1 tahun di posisi yan...
# 12  Pria / Wanita usia 17-35 tahun Pengalaman / no...
# 13  Maksimal 30 Tahun. Minimal Pendidikan SMA/Sede...
# 14  Laki-laki, Max. 33 tahun  Min. SMK/SMA dari se...
# 15  Keahlian: Microsoft Office Usia Minimal 18 Tah...
# 16  Laki-laki / Perempuan Pendidikan min. SMA/SMK ...
# 17  Wanita Memiliki pengalaman sebagai host menjad...
# 18  Usia 18 45 tahun Pendidikan min SMA / SMK / Pa...
# 19  A Master/Doctoral Degree in Marketing, Busines...
# 20  Usia 18-35 Tahun Minimal Pendidikan SMA/Sedera...
# 21  Pendidikan Min. SMA/SMK Usia Max. 30 Tahun Mem...
# 22   Pria & Wanita , Usia Maks.35thn Pend.Min SMA ...
# 23  Pria/ Wanita Usia 20 30 tahun Minimal pendidik...
# 24  Usia 18-30 tahun Minimal lulusan SMA / SMK / s...
# 25  Lulusan S1 atau sedang berkuliah sesuai dengan...
# 26  Usia maksimal 35 tahun Memiliki pengalaman ker...
# 27  Umur Max 25 tahun Mempunyai SIM dan kendaraan ...
# 28  Mencari orang untuk membantu pemindahan Fasili...
# 29  Pengalaman min. 1 tahun sebagai Kitchen Crew a...
# 30  Mampu berkomunikasi dengan Baik. Teliti dan me...
# 31  Wanita usia 18 s/d 25 tahun, mampu kerja di ba...
# 32  Strong foundation in computer science and prob...
# 33  Minimal pendidikan SMA/SMK/D3  Memiliki pengal...
# 34  Minimal Pendidikan SMA atau sederajat Memiliki...
# 35  Pria Usia Maksimal 40 Tahun  Pendidikan Minima...
# 36  Pendidikan min SMA / SMK / Paket C sederajat (...
# 37  Usia 25 35 tahun Pria/ Wanita Bisa menawarkan ...
# 38  SMA/SMU/SMK (Preferred) Graphic Design: 1 year...
# 39  wanita Minimal SMA/SMK SEDERAJAT Bersedia berk...
# 40  Usia maksimal 45 tahun  Pendidikan: SMA / D3 /...
# 41  Pendidikan terakhir minimal SMA/SMK Memiliki k...
# 42  Memliki pengalaman min.1 tahun  Memiliki komun...
# 43  Wanita, Pendidikan minimal SMA/SMK. Maksimal u...
# 44  Final year college student/fresh graduate are ...
# 45  Pria & wanita Usia 18 s/d 35 tahun Pendidikan ...
# 46  Pendidikan minimal SMA sederajat Memiliki Peng...
#
#                                      Current Position
# 0                                  Merchandiser Staff  \
# 1                                      Admin Produksi
# 2                        Sales Kartu Kredit Perbankan
# 3                                    Anggota Security
# 4                                   Customer Service
# 5                                        Data Analyst
# 6                                       Telemarketing
# 7                 Field Agent Home Credit Indonesia
# 8          TELEMARKETING PERBANKAN AREA JAKARTA PUSAT
# 9                                      Telegeneralist
# 10                            SALES AGENT / SPG / SPB
# 11                                     Pancake Pastry
# 12                                         Waiter / s
# 13                                      Sales Canvas
# 14                                    Sales Marketing
# 15                          Staff Admin Money Changer
# 16                              Telemarketing Officer
# 17                    Host Live Streaming TikTok Shop
# 18  KOLEKTOR Home Credit Indonesia Area CAKUNG JAK...
# 19  Part Time Lecturer in International Business M...
# 20                             Telemarketing Borrower
# 21                          Sales Promotor Elektronik
# 22                        Sales Representative HORECA
# 23                             Admin Business Banking
# 24                Operator Live Streaming Tiktok Shop
# 25                                    Tutor Sosiologi
# 26                                        Cook Pastry
# 27                                       Sales Toyota
# 28                                      Sales Advisor
# 29                                      Cook, Kitchen
# 30                      Staff Marketing Money Changer
# 31                                         Beautician
# 32                                 Software Engineer
# 33                                    QRIS Canvasser
# 34                                  Sales Acquisition
# 35                                             Kernet
# 36                Field Agent Home Credit Indonesia
# 37                 TELESALES OFFICER  / Telemarketing
# 38                                     Graphic Design
# 39                                              ADMIN
# 40                                   Marketing Sales
# 41                               Sales Representative
# 42                                   Field Collection
# 43                                               SPG
# 44                                    Apprenticeship
# 45                                       Staff Gudang
# 46                                  Digital Marketing
#
#                                         Alternative 1
# 0                                       Admin Kitchen  \
# 1                  GRAPHIC DESIGNER & CONTENT CREATOR
# 2                                 Host Live Streaming
# 3                  CDP / COOK / COOK HELPER / STEWARD
# 4                                        Admin Sosmed
# 5                                            Cashier
# 6                                        Sales Toyota
# 7                                      Crew Restoran
# 8                            Sales Promotor Handphone
# 9                                     Content Creator
# 10                                    Sales Executive
# 11                                          Sales MD
# 12                                Host Live Streaming
# 13                                   Anggota Security
# 14                                              Kasir
# 15                                    Sales Executive
# 16                                       Sales Toyota
# 17                                      Guru Geografi
# 18                                     Crew Restoran
# 19                                         Marketing.
# 20                                   Security Officer
# 21                                       Sales Toyota
# 22                                       Sales Toyota
# 23                                    Sales Executive
# 24                                Host Live Streaming
# 25                                 Software Engineer
# 26  Consultant as Sustainable Palm Oil Policy Spec...
# 27                                          Sales MD
# 28                                     DRIVER JAKARTA
# 29  Consultant as Communications Officer for Food ...
# 30                                       Sales Toyota
# 31                                    Sales Executive
# 32                                  Halal Supervisor
# 33                                           Operator
# 34                                       Sales Toyota
# 35                                    Sales Executive
# 36                                     Crew Restoran
# 37                                       Crew Outlet
# 38                                     DRIVER JAKARTA
# 39                                       Sales Toyota
# 40                                Host Live Streaming
# 41                                          Sales MD
# 42                                       Sales Toyota
# 43                                   Anggota Security
# 44                                  Halal Supervisor
# 45                                    Sales Executive
# 46                                         Marketing.
#
#                                         Alternative 2
# 0                                        Sales Toyota
# 1                                  Host/Pembawa Acara
# 2                                        Sales Toyota
# 3                                     Sales Executive
# 4                                        Sales Toyota
# 5                                 SPG Regular Mobile
# 6                       Senior Cook Indonesian Food
# 7                                              Driver
# 8   Consultant as Communications Officer for Food ...
# 9                                        Sales Toyota
# 10                                       Admin Proyek
# 11                                              Admin
# 12  Apprenticeship – Digital Marketing for App Cam...
# 13                                         SPV Gudang
# 14                                       Sales Toyota
# 15                                       Sales Toyota
# 16                                Host Live Streaming
# 17                            Guru Bahasa Inggris SMA
# 18                                             Driver
# 19                                  Halal Supervisor
# 20                                    Sales Executive
# 21                         SALES MARKETING EXECUTIVE
# 22                                        Cook Helper
# 23                              Administrasi Warhouse
# 24                                            Gondola
# 25                        Software Design Instructor
# 26                                       Sales Toyota
# 27                                        Cook Helper
# 28  Consultant as Communications Officer for Food ...
# 29                                        CSA  BEKASI
# 30                                          Sales MD
# 31  Consultant as Communications Officer for Food ...
# 32                     Sales Area/Business Consultant
# 33                                     SALES PROMOTOR
# 34                                 Cook Helper Pastry
# 35                      Senior Cook Indonesian Food
# 36                                             Driver
# 37                                       Sales Toyota
# 38  Consultant as Communications Officer for Food ...
# 39                                    Sales Executive
# 40                                       Data Analyst
# 41                         Posisi kasir untuk Jakarta
# 42                         SALES MARKETING EXECUTIVE
# 43                                    Staff Logistik
# 44                     Sales Area/Business Consultant
# 45                                Host Live Streaming
# 46                      Senior Cook Indonesian Food
